# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train= pd.read_csv('diabetes2.csv')

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E4E6-3BED
#
#  Directory of C:\Users\hp\Downloads
#
# 11/29/2021  04:43 PM    <DIR>          .
# 11/29/2021  04:43 PM    <DIR>          ..
# 08/26/2021  10:09 AM        22,681,897 (Schaum’s Outlines) Seymour Lipschutz - Essential Computer Mathematics-McGraw-Hill Education (1982).pdf
# 11/29/2021  04:21 PM    <DIR>          .ipynb_checkpoints
# 10/19/2021  03:27 AM           310,982 01-Matplotlib Concepts Lecture.ipynb
# 10/04/2021  03:39 AM            20,572 01-NumPy Arrays.ipynb
# 09/30/2021  02:22 AM            12,138 01-Series.ipynb
# 10/19/2021  03:29 AM           854,631 02-Advanced Matplotlib Concepts.ipynb
# 09/30/2021  02:15 AM            14,692 02-Numpy Indexing and Selection.ipynb
# 10/21/2021  04:07 PM           123,426 03-Matplotlib Exercises (1).ipynb
# 10/19/2021  03:24 AM           119,540 03-Matplotlib Exercises.ipynb
# 09/30/2021  02:15 AM             6,937 03-Numpy Operations.ipynb
# ...

# %%
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Pregnancies',data=train,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Glucose',data=train,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='BloodPressure',data=train,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Insulin',data=train,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='SkinThickness',data=train,palette='RdBu_r')

# %%
sns.distplot(train['Age'].dropna(),kde=False,color='darkred',bins=30)

# %%
train['Age'].hist(bins=30,color='darkred',alpha=0.7)

# %%
sns.countplot(x='Insulin',data=train)

# %%
train['BMI'].hist(color='green',bins=40,figsize=(8,4))

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Pregnancies',y='Age',data=train,palette='winter')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('Insulin',axis=1), 
                                                    train['Insulin'], test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.97      0.67       117
#           14       0.00      0.00      0.00         1
#           23       0.00      0.00      0.00         1
#           25       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         1
#           32       0.00      0.00      0.00         1
#           36       0.00      0.00      0.00         1
#           38       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         1
#           41       0.00      0.00      0.00         1
#           49       0.00      0.00      0.00         5
#           54       0.00      0.00      0.00         1
#           55       0.00      0.00      0.00         1
#           56       0.00      0.00      0.00         2
#           57       0.00      0.00      0.00         0
#           58       0.00      0.00      0.00         2
# ...
